# %% [markdown]
# # DATASCI 350 - Data Science Computing
#
# ## Assignment 08 - Cloud computing
#
# ### Instructions
#
# This assignment evaluates your understanding of lectures 16 and 17: the four service models, virtualisation, the AWS catalogue, launching and terminating an EC2 instance, SSH keys and their permissions, `scp`, `apt`, and CloudShell.
#
# Most tasks are reading and reasoning about material you already have. You read a pasted transcript, a table, or a note from the launch wizard, and you explain what it means.
#
# Three tasks ask you to run commands on your own laptop: tasks 05, 06 and 12. They need nothing but a terminal and Python 3, and none of them touches AWS.
#
# Task 11 needs the AWS account you created in lecture 16. It runs in CloudShell, the terminal in the browser, which is free. No task in this assignment starts an EC2 instance, so nothing here spends your credits.
#
# **Never paste a private key, an account number, or an access key anywhere in your submission.** The private key file from task 05 is the one without `.pub` at the end, and its contents must not appear in what you hand in. If you include a screenshot from the AWS console, blank out the account number before you submit it.
#
# Task 12 needs pandas. If `import pandas` fails, run `pip install pandas`.
#
# Your outputs will not match mine, and they do not need to. Fingerprints, file dates and generated data differ between machines. Report what your machine did and paste the actual output. Do not edit outputs.
#
# You must complete this assignment individually. You may use notes, books, and AI tools, but you must submit original work. I strongly recommend that you do not use AI tools to generate your solutions, as this will not help you learn the material. Acknowledge all resources used, including input from classmates and AI, in a short note at the end of your submission. If you are unsure about permissible resources or proper acknowledgement, please ask the instructor.
#
# ### Submission
#
# Please submit your solutions as either a single Jupyter notebook or a PDF file. For each task, paste the commands you ran, any script you wrote or edited, the output you got, and your written answer where the task asks for one. Screenshots are welcome but not required if you paste the text. Submit your completed assignment to Canvas.

# %% [markdown]
# ### Task 01
#
# Here are four jobs. Each one is done with a cloud service, and each one sits at a different level of the stack.
#
# 1. Reading your email in Gmail.
# 2. Deploying a Flask application you wrote to AWS Elastic Beanstalk, which supplies the servers.
# 3. Renting an Ubuntu virtual machine and installing Python, pip and your own libraries on it yourself.
# 4. Registering one Python function that AWS runs every time a file lands in a storage bucket.
#
# For each job, say whether it is SaaS, PaaS, IaaS or FaaS, and say who patches the operating system, you or the provider. One line per job is enough.
#
# Then answer in a few sentences: two of these four leave the operating system to the provider. What do you give up in exchange for that?
#
# Hint: the "Cloud computing services" slides of lecture 16, and the "Comparison of cloud services" table.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 02
#
# Lecture 16 covered three AWS storage services: S3, EBS and EFS. Here are three jobs.
#
# 1. A 40 TB archive of scanned documents that the department reads twice a year.
# 2. The data directory of a PostgreSQL database running on a single EC2 instance.
# 3. A folder of shared images that six EC2 instances read at the same time while a job runs.
#
# For each job, name the service you would use and give one sentence saying why. Then, in a few sentences, say what stops you from using EBS for job 3.
#
# Hint: the three "Cloud storage" slides of lecture 16.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 03
#
# On 19 October 2025 the `us-east-1` region failed for roughly fifteen hours. Lecture 16 described the cause like this: two of DynamoDB's DNS programs updated the same record at once, the stale one finished last, and the address for `dynamodb.us-east-1.amazonaws.com` was left empty.
#
# Answer in one paragraph. First, explain in your own words what a race condition is, and say which part of that description makes this one. Second, the record that went empty belongs to DynamoDB, a database service. Explain why launching an EC2 instance and signing in to the AWS console both failed, even though neither is DynamoDB.
#
# Hint: the "When AWS has a bad night" slide.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 04
#
# Lecture 16 gave S3 a durability figure of 99.999999999%, eleven nines. The same region went down for about fifteen hours in October 2025, and during those hours a great many people could not read their files.
#
# Both of those statements are true at the same time. Answer in one paragraph: what does durability actually promise, what does availability promise, and which of the two did the outage break? Finish by naming one thing eleven nines of durability does protect you from that an outage does not.
#
# Hint: the "Amazon S3" slide and the "When AWS has a bad night" slide.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 05
#
# This task creates a practice SSH key pair on your own laptop. It has nothing to do with AWS, and you will not connect to anything with it.
#
# Make a new folder outside your course repository, open a terminal in it, and run these three commands:
#
# ```bash
# ssh-keygen -t ed25519 -f datasci350-practice -N ""
# ls -l
# ssh-keygen -l -f datasci350-practice.pub
# ```
#
# The `-t ed25519` flag picks the key type, `-f` names the output file, and `-N ""` sets an empty passphrase so the command does not stop to ask you for one.
#
# Paste the output of all three commands.
#
# **Never paste the contents of `datasci350-practice` anywhere.** That is the private key. It is the half that proves you are you, and it is the reason the lecture told you a `.pem` file never goes into a Git repository. The `.pub` file is the half you are allowed to share, and pasting the fingerprint line is also fine.
#
# Then answer in a few sentences: `ssh-keygen` wrote two files. Which of the two would you send to a server administrator who needs to give you access, and what would the other one let somebody do if they had it?
#
# Hint: the "Step 03: Choose an SSH key pair" slide of lecture 17, and the "Next class" slide of lecture 16.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 06
#
# Stay in the folder from task 05. Run these four commands and paste the output of each:
#
# ```bash
# chmod 644 datasci350-practice
# ls -l datasci350-practice
# chmod 400 datasci350-practice
# ls -l datasci350-practice
# ```
#
# Then answer two things.
#
# 1. Read `400` digit by digit. There are three digits, and each one belongs to a different set of people. Say which set each digit is for, and say what permission the value of each digit grants. Do the same for `644`.
# 2. After the first `chmod`, the file is readable by everybody with an account on the machine. SSH refuses to use a key in that state and stops with an error rather than connecting. In a few sentences, say why refusing is the right behaviour, and name the group of students in this course who hit this error most often and why.
#
# Hint: the "Step 06: Log in to the EC2 instance through SSH" slide of lecture 17, and the WSL slide.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 07
#
# When you pick an instance type in the launch wizard, the `Summary` panel on the right shows a blue `Free tier` note. It describes the offer as 750 hours a month of `t2.micro` for a year.
#
# That note is wrong for your account. Answer in one paragraph: why is it wrong, what changed and when, and what does your account get instead of those 750 hours? Finish by naming the instance type you were told to choose in class, and say what happens to your bill if you pick `t2.micro` because the note told you it was free.
#
# Hint: the "Which instance type is free?" slide of lecture 17.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 08
#
# In Activity 01 of lecture 17 you connected to your instance with an extra flag on the end:
#
# ```bash
# ssh -i "<your-key>.pem" ubuntu@<public_IPv4_DNS_address> -L 8000:localhost:8888
# ```
#
# You then started Jupyter on the instance, and it printed a line like this:
#
# ```text
# http://localhost:8888/?token=...
# ```
#
# Answer in one paragraph. First, read `-L 8000:localhost:8888` piece by piece: say which machine each of the two ports is on, and say which machine `localhost` refers to inside that flag. Second, explain why the browser on your laptop opens `http://localhost:8000` when Jupyter printed 8888. Third, say what happens to the notebook page in the browser if you close the terminal window running that `ssh` command.
#
# Hint: the "Activity 01" slides of lecture 17.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 09
#
# Here are two `scp` commands. They differ only in the order of the two paths.
#
# ```bash
# scp -i datasci350.pem results.csv ubuntu@ec2-3-84-12-9.compute-1.amazonaws.com:~
# ```
#
# ```bash
# scp -i datasci350.pem ubuntu@ec2-3-84-12-9.compute-1.amazonaws.com:~/results.csv .
# ```
#
# For each command, say which direction the file moves, and say which machine you must be sitting on when you type it. Then say what the trailing `.` in the second command means, and what the `:~` at the end of the first command means.
#
# Finish with this case, in a few sentences. A classmate opened an SSH session to the instance, and then typed the second command at the instance's own prompt. It failed. Say what that command was actually trying to do from there, and what they should have done instead.
#
# Hint: the "Adding files to your instance" slide of lecture 17.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 10
#
# A classmate connected to a fresh Ubuntu instance, installed pip, and tried to install pandas. This is what their terminal showed:
#
# ```text
# ubuntu@ip-172-31-13-146:~$ pip3 install pandas
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# ```
#
# Answer in one paragraph. What is Ubuntu protecting here, and what is it protecting it from? Then say which of the two routes lecture 17 gives you, `sudo apt install python3-<package>` or a virtual environment built with `python3 -m venv env` and then `source env/bin/activate`, you would use to get pandas onto a throwaway instance, and why you picked that one. Finish by saying what the `--break-system-packages` flag in the last line would do, and why the lecture does not suggest it.
#
# Hint: the "Step 07: Update and install software" slide of lecture 17.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 11
#
# This task needs the AWS account you created in lecture 16. It uses CloudShell, which is free: you pay only for AWS resources you drive from it, and this task drives none.
#
# Sign in to the AWS console and open CloudShell from the icon in the bottom left corner of the page. There is nothing to install and nothing to configure. Wait for the prompt, then run these two commands:
#
# ```bash
# aws sts get-caller-identity
# aws ec2 describe-instances --output table
# ```
#
# Paste the output of both. **Blank out your twelve-digit account number** everywhere it appears, in the text and in any screenshot, before you submit. Replace it with `XXXXXXXXXXXX`.
#
# If you have never launched an instance, the second command prints only a small table header with no rows underneath. That is the correct answer for your account, so paste what you get.
#
# Then answer in a few sentences: you configured no keys and typed no password into CloudShell, and `aws sts get-caller-identity` still knew who you were. Explain why. Then say one thing you would have had to do first to run the same two commands from the terminal on your own laptop.
#
# Hint: the "AWS CloudShell" and "CloudShell commands" slides of lecture 17.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 12
#
# This task needs pandas.
#
# Lecture 17 used a script called `weather_data.py` to build a small dataset on your laptop before uploading it to an instance. Download it and run it:
#
# ```bash
# curl -O https://raw.githubusercontent.com/danilofreire/datasci350/main/lectures/lecture-17/weather_data.py
# python3 weather_data.py
# ```
#
# It writes a file called `weather_data.txt` in the same folder.
#
# Before you write any code, open `weather_data.txt` and look at it. Run `head -4 weather_data.txt` and paste what you see. In one or two sentences, describe the format: what is on the first line, what is on the second, and what separates the columns. Getting this wrong is the reason most attempts at this task fail, so do it first.
#
# Then write a script that reads the file and prints three things:
#
# 1. the number of days in the data,
# 2. the mean of `temp_high`, to one decimal place,
# 3. the date on which `temp_high - temp_low` was largest.
#
# The first line of the file must not end up in your data. Paste your script and its output.
#
# Then answer in a few sentences: your three numbers will not match a classmate's dates, but the temperatures will match. Look at the top of `weather_data.py` and explain why.
#
# Hint: the "Activity 02" slides of lecture 17 show `weather_analysis.py` reading the same file. It handles the first line in one way; pandas offers another. Either is fine, and your answer should say which you used.

# %% [markdown]
# *Commands, output, and answer here.*
