# %% [markdown]
# # DATASCI 350 - Data Science Computing
#
# ## Assignment 04 - Git in depth
#
# ### Instructions
#
# This assignment evaluates your understanding of Git beyond the basics. Tasks 01 to 08 go deeper into commands from lectures 05 to 08, with all setup steps given. Tasks 09 to 12 cover commands we have not discussed in class: research how they work and explain each one in your own words. Good starting points are `git help <command>` and the free Pro Git book (<https://git-scm.com/book>).
#
# Several tasks use the `reading-list` repository you built in assignment 03. If you no longer have it on your computer, clone it back with `gh repo clone USERNAME/reading-list`. If you never built it, work through assignment 03 first and create it: the tasks below assume it exists, with the commits, the branch and the merged pull request from that assignment. Where a task needs a fresh practice repository, the setup commands are given in full: run them exactly as written, then solve the task. Create those practice repositories in a folder outside `reading-list`, never inside it.
#
# Run these commands in a terminal, then paste the commands and their output into the answer cell below each task. Some tasks ask you to edit a file or read a help page, which a notebook cell cannot do.
#
# You must complete this assignment individually. You may use notes, books, and AI tools, but you must submit original work. I strongly recommend that you do not use AI tools to generate your solutions, as this will not help you learn the material. Acknowledge all resources used, including input from classmates and AI, in a short note at the end of your submission. If you are unsure about permissible resources or proper acknowledgement, please ask the instructor.
#
# ### Submission
#
# Please submit your solutions as either a single Jupyter notebook or a PDF file. For each task, record the command(s) you used, their output, and a one- or two-sentence explanation in your own words. Screenshots are welcome but not required if you paste the commands and their output. Submit your completed assignment to Canvas.

# %% [markdown]
# ### Task 01: stash basics
#
# In your `reading-list` repository, add one line to `README.md` but do not commit it. Run `git stash`, then show with `git status` that the working tree is clean. Bring the change back with `git stash pop`. Now discard it with `git restore README.md`. `git restore` throws away uncommitted changes to a file and puts it back to the state of the last commit, which is what `git status` suggests when a file is modified. It cannot be undone, so use it only when you are sure. Run `git status` again and check that the working tree is clean. In one sentence: where was your change while it was stashed?

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 02: amend a forgotten file
#
# In `reading-list`, create a file `notes.md` with one line and commit it with the message "Add notes". Then create a second file `todo.md`, which you meant to include in that commit. Add it to the previous commit with `git add` and `git commit --amend --no-edit`. Show with `git log --oneline` that there is still only one "Add notes" commit.

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 03: log detective
#
# Run `git log --oneline` in `reading-list`, after finishing task 02. How many commits does the repository have at that point, and what is the hash of the oldest one? In one sentence: what information does the full `git log` show that `--oneline` leaves out?

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 04: two diffs
#
# In `reading-list`, modify any file and run `git diff`. Now stage the file and run `git diff` again, then `git diff --staged`. Paste the three outputs. In a few sentences: is the second `git diff` empty? Why?

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 05: soft vs hard reset
#
# Warning: `git reset --hard` deletes work permanently. Run it only inside the two practice repositories you create for this task, never in a repository you care about.
#
# Create two identical practice repositories. Run this setup once as written, then run it a second time with `reset-hard` in place of `reset-soft` in the `mkdir` line and the first `cd` line:
#
# ```bash
# mkdir reset-soft
# cd reset-soft
# git init -b main
# echo "line one" > notes.txt
# git add notes.txt
# git commit -m "First commit"
# echo "line two" >> notes.txt
# git commit -am "Second commit"
# cd ..
# ```
#
# In `reset-soft`, run `git reset --soft HEAD~1`. In `reset-hard`, run `git reset --hard HEAD~1`. For each repository, report what `git status` shows and what `notes.txt` contains. Two sentences: what did each reset keep, and what did it throw away?

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 06: detached HEAD
#
# In `reading-list`, first discard the change you staged in Task 04: unstage it with `git restore --staged FILE`, then throw it away with `git restore FILE`, and check that `git status` reports a clean tree. Check out your oldest commit by its hash (from Task 03). Files added in later commits, such as `notes.md` and `books/`, disappear while you are there, and `drafts/` may show as untracked: nothing is lost. Git prints a warning about a "detached HEAD" state: explain in your own words what it means. Then return safely with `git switch main`.

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 07: conflict clinic
#
# Run this setup exactly as written. The final command produces a merge conflict on purpose:
#
# ```bash
# mkdir conflict-practice
# cd conflict-practice
# git init -b main
# echo "The project starts here." > plan.txt
# git add plan.txt
# git commit -m "Add plan"
# git switch -c feature
# echo "The project starts with data cleaning." > plan.txt
# git commit -am "Update plan on feature"
# git switch main
# echo "The project starts with data collection." > plan.txt
# git commit -am "Update plan on main"
# git merge feature
# ```
#
# Open `plan.txt`, resolve the conflict by keeping the sentence you prefer and removing the marker lines, then stage the file and complete the merge with `git commit --no-edit` (Git has already written the merge message; without `--no-edit` it opens an editor). In two sentences: what do the three marker lines (`<<<<<<<`, `=======`, `>>>>>>>`) delimit?

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 08: GitHub CLI starter
#
# Using the GitHub CLI from lecture 07: check that you are logged in with `gh auth status`, open your `reading-list` repository in the browser with `gh repo view --web`, and list its issues from the terminal (add `--state all` if you have closed the issue). The issue you opened in assignment 03 appears in the list. If `gh` does not work on your machine, run `gh auth login` first (see assignment 03). If it still does not work, do the same three steps on the GitHub website instead and say so in your answer.

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 09: tag a release (research)
#
# Push any commits you have not pushed yet with `git push`. This push normally succeeds, and then you can go straight to the tag below. It is usually rejected only if you amended a commit that was already on GitHub. If that happens to you, since nobody else uses this repository, push with `git push --force` and explain in your answer why Git refused the first push and why forcing is safe here (and when it would not be).
#
# Then create an annotated tag named `v1.0` on your `reading-list` repository with `git tag -a v1.0 -m "First release"` (without `-m`, Git opens an editor) and push it with `git push origin v1.0`, because a plain `git push` does not send tags. Paste the URL of the tag page, `https://github.com/USERNAME/reading-list/releases/tag/v1.0`. One sentence: what is the difference between a lightweight and an annotated tag?

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 10: search the history (research)
#
# In `reading-list`, find the commit or commits whose message contains the word "books" without reading the whole log: use an option of `git log` that filters by message. Then find all commits made by you, filtering by author. Both options are listed in `git log --help`. That page is long, so press `/`, type the word you are looking for, press Enter, and `n` to jump to the next match. Press `q` to leave. Report both commands. The first search may return more than one commit: explain why each one matched.

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 11: make Git yours (research)
#
# Create two Git aliases with `git config --global`: `git st` for `status` and `git last` for showing only the most recent commit. They stay in your configuration after this assignment, which is the point of making them. Show both aliases working. One sentence: in which file does Git store them?

# %% [markdown]
# *Commands, output, and explanation here.*

# %% [markdown]
# ### Task 12: committed by mistake (research)
#
# Run this setup:
#
# ```bash
# mkdir secret-practice
# cd secret-practice
# git init -b main
# echo "api_key=12345" > secrets.txt
# git add secrets.txt
# git commit -m "Add config"
# ```
#
# The key file should never have been committed. Make Git stop tracking `secrets.txt` while keeping the file on disk, commit that change, and make sure the file cannot be accidentally committed again. Verify with `git ls-files` that `secrets.txt` is no longer tracked, and with `ls` that it is still on disk. Three sentences: what did you do, why does deleting the file with `rm` not solve the problem, and what would you still have to do if this commit had already been pushed to GitHub?

# %% [markdown]
# *Commands, output, and explanation here.*
